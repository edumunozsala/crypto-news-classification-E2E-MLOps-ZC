# %%
import joblib
import re
import string

import numpy as np
import pandas as pd

from sklearn.datasets import fetch_20newsgroups
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.metrics import accuracy_score, cohen_kappa_score, f1_score, classification_report
from sklearn.model_selection import StratifiedKFold, train_test_split
from sklearn.naive_bayes import MultinomialNB

# %%
data = pd.read_csv('cryptonews.csv')
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31037 entries, 0 to 31036
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   date       31037 non-null  object
#  1   sentiment  31037 non-null  object
#  2   source     31037 non-null  object
#  3   subject    31037 non-null  object
#  4   text       31037 non-null  object
#  5   title      31037 non-null  object
#  6   url        31037 non-null  object
# dtypes: object(7)
# memory usage: 1.7+ MB

# %%
data.head(10)
# Out:
#                   date                                          sentiment  \
# 0  2023-12-19 06:40:41  {'class': 'negative', 'polarity': -0.1, 'subje...
# 1  2023-12-19 06:03:24  {'class': 'neutral', 'polarity': 0.0, 'subject...
# 2  2023-12-19 05:55:14  {'class': 'positive', 'polarity': 0.05, 'subje...
# 3  2023-12-19 05:35:26  {'class': 'positive', 'polarity': 0.5, 'subjec...
# 4  2023-12-19 05:31:08  {'class': 'neutral', 'polarity': 0.0, 'subject...
# 5  2023-12-19 05:25:00  {'class': 'negative', 'polarity': -0.01, 'subj...
# 6  2023-12-19 04:50:11  {'class': 'positive', 'polarity': 0.3, 'subjec...
# 7  2023-12-19 04:10:00  {'class': 'neutral', 'polarity': 0.0, 'subject...
# 8  2023-12-19 04:00:01  {'class': 'neutral', 'polarity': 0.0, 'subject...
# 9  2023-12-19 02:59:59  {'class': 'negative', 'polarity': -0.08, 'subj...
#
#           source     subject  \
# 0     CryptoNews     altcoin
# 1     CryptoNews  blockchain
# 2     CryptoNews  blockchain
# 3  CoinTelegraph  blockchain
# 4  CoinTelegraph    ethereum
# 5   CryptoPotato     bitcoin
# 6     CryptoNews     bitcoin
# 7   CryptoPotato     bitcoin
# 8     CryptoNews  blockchain
# 9  CoinTelegraph     bitcoin
#
#                                                 text  \
# 0  Grayscale CEO Michael Sonnenshein believes the...
# 1  In an exclusive interview with CryptoNews, Man...
# 2  According to the Federal Court ruling on Decem...
# 3  Some suggest EVM inscriptions are the latest w...
# 4  A decision by bloXroute Labs to start censorin...
# 5  Yonsei found that during BTC’s rally in early ...
# 6  Cathie Wood led ARK Invest fund sold around 80...
# 7  Bitcoin's 150% surge pales in comparison to th...
# 8  The South Korean city of Busan is edging close...
# 9  The SEC has pushed back its decision on a rost...
#
#                                                title  \
# 0  Grayscale CEO Calls for Simultaneous Approval ...
# 1  Indian Government is Actively Collaborating Wi...
# 2  Judge Approves Settlement: Binance to Pay $1.5...
# 3  Why a gold rush for inscriptions has broken ha...
# 4  ‘Concerning precedent’ — bloXroute Labs' MEV r...
# 5  Is This Why Bitcoin’s Price Rally Was Halted? ...
# 6  Cathie Wood’s Ark Invest Sells $27.6 Million i...
# 7  Bitcoin Soared 150% in 2023 But These Companie...
# 8  South Korean City Busan Names Digital Exchange...
# 9  SEC delays several Ethereum ETFs, pushing fina...
#
#                                                  url
# 0  https://cryptonews.comhttps://cryptonews.com/n...
# 1  https://cryptonews.comhttps://cryptonews.com/n...
# 2  https://cryptonews.comhttps://cryptonews.com/n...
# 3  https://cointelegraph.com/news/inscriptions-ev...
# 4  https://cointelegraph.com/news/concerning-prec...
# 5  https://cryptopotato.com/is-this-why-bitcoins-...
# 6  https://cryptonews.comhttps://cryptonews.com/n...
# 7  https://cryptopotato.com/bitcoin-soared-150-in...
# 8  https://cryptonews.comhttps://cryptonews.com/n...
# 9  https://cointelegraph.com/news/sec-delays-ethe...

# %% [markdown]
# Create the larget label column

# %%
data['label']= data['sentiment'].map(lambda x: eval(x)['class'])
data.head(5)
# Out:
#                   date                                          sentiment  \
# 0  2023-12-19 06:40:41  {'class': 'negative', 'polarity': -0.1, 'subje...
# 1  2023-12-19 06:03:24  {'class': 'neutral', 'polarity': 0.0, 'subject...
# 2  2023-12-19 05:55:14  {'class': 'positive', 'polarity': 0.05, 'subje...
# 3  2023-12-19 05:35:26  {'class': 'positive', 'polarity': 0.5, 'subjec...
# 4  2023-12-19 05:31:08  {'class': 'neutral', 'polarity': 0.0, 'subject...
#
#           source     subject  \
# 0     CryptoNews     altcoin
# 1     CryptoNews  blockchain
# 2     CryptoNews  blockchain
# 3  CoinTelegraph  blockchain
# 4  CoinTelegraph    ethereum
#
#                                                 text  \
# 0  Grayscale CEO Michael Sonnenshein believes the...
# 1  In an exclusive interview with CryptoNews, Man...
# 2  According to the Federal Court ruling on Decem...
# 3  Some suggest EVM inscriptions are the latest w...
# 4  A decision by bloXroute Labs to start censorin...
#
#                                                title  \
# 0  Grayscale CEO Calls for Simultaneous Approval ...
# 1  Indian Government is Actively Collaborating Wi...
# 2  Judge Approves Settlement: Binance to Pay $1.5...
# 3  Why a gold rush for inscriptions has broken ha...
# 4  ‘Concerning precedent’ — bloXroute Labs' MEV r...
#
#                                                  url     label
# 0  https://cryptonews.comhttps://cryptonews.com/n...  negative
# 1  https://cryptonews.comhttps://cryptonews.com/n...   neutral
# 2  https://cryptonews.comhttps://cryptonews.com/n...  positive
# 3  https://cointelegraph.com/news/inscriptions-ev...  positive
# 4  https://cointelegraph.com/news/concerning-prec...   neutral

# %%
data['label'].value_counts()
# Out:
# label
# positive    13964
# neutral     10555
# negative     6518
# Name: count, dtype: int64

# %% [markdown]
# ## Create the Processor

# %%
import spacy
import re
from sklearn.base import BaseEstimator, TransformerMixin

# %%
class LinguisticPreprocessor(BaseEstimator, TransformerMixin):
    """
    Preprocesador lingüístico para limpieza y normalización de texto, incluida la eliminación de stopwords.

    Attributes
    ----------
    nlp : spacy.language.Language
        Instancia de spaCy para el procesamiento del lenguaje.
    stopwords : set
        Conjunto de stopwords.
    """
    def __init__(self, nlp):
        self.nlp = nlp
        self.stopwords = nlp.Defaults.stop_words


    def lemmatize_and_remove_stopwords(self, doc):
        """
        Lematiza el documento y elimina las stopwords.

        Parameters
        ----------
        doc : spacy.tokens.doc.Doc
            Documento procesado por spaCy.

        Returns
        -------
        str
            Texto lematizado sin stopwords.
        """
        return " ".join([token.lemma_ for token in doc if not token.is_punct and token.text.lower() not in self.stopwords])

    def fit(self, X, y=None):
        """
        Método de ajuste requerido por scikit-learn TransformerMixin. No se realiza ningún ajuste.

        Parameters
        ----------
        X : iterable
            Textos a preprocesar.
        y : None
            Ignorado.

        Returns
        -------
        self
        """
        return self

    def transform(self, X, y=None):
        """
        Transforma los textos aplicando limpieza, eliminación de HTML, lematización y eliminación de stopwords.

        Parameters
        ----------
        X : iterable
            Textos a preprocesar.

        Returns
        -------
        list
            Lista de textos preprocesados.
        """
        transformed_X = []
        for text in X:
            #text = self.remove_html_tags(text)
            text = re.sub(r'\s+', ' ', text).strip()  # Elimina espacios extras
            doc = self.nlp(text)
            transformed_text = self.lemmatize_and_remove_stopwords(doc)
            transformed_X.append(transformed_text)
        return transformed_X

# %%
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from sklearn.multiclass import OneVsRestClassifier
from sklearn.svm import LinearSVC
from sklearn.naive_bayes import MultinomialNB
from sklearn.ensemble import RandomForestClassifier
#from sklearn.linear_model import LogisticRegression

from sklearn.pipeline import Pipeline

# %%
# Cargar spaCy Language model
nlp = spacy.load("en_core_web_sm")

# Instanciar el preprocesador
preprocessor = LinguisticPreprocessor(nlp)

# Crear el pipeline
pipeline = Pipeline([
    ('preprocess', preprocessor),
    ('vectorizer', CountVectorizer()),
    #('classifier', OneVsRestClassifier(LinearSVC(), n_jobs=1)) #53 63 71
    #('classifier', MultinomialNB()) 0.4 0.45 0.65
    #('classifier', LinearSVC()) #50 64 70
    #('classifier', RandomForestClassifier(n_estimators=250, max_depth=4, random_state=0))
        #RandomForestClassifier(n_estimators=200, max_depth=3, random_state=0)
    ('classifier', LinearSVC()) #50 64 70
])

# %% [markdown]
# ## Preprocess the Label

# %%
data.head(1)
# Out:
#                   date                                          sentiment  \
# 0  2023-12-19 06:40:41  {'class': 'negative', 'polarity': -0.1, 'subje...
#
#        source  subject                                               text  \
# 0  CryptoNews  altcoin  Grayscale CEO Michael Sonnenshein believes the...
#
#                                                title  \
# 0  Grayscale CEO Calls for Simultaneous Approval ...
#
#                                                  url     label
# 0  https://cryptonews.comhttps://cryptonews.com/n...  negative

# %%
label_dict={'positive': 1, 'neutral': 0, 'negative': -1}
data['label'] = data['label'].map(label_dict)
#data['label'].map(label_dict)
data.head(5)
# Out:
#                   date                                          sentiment  \
# 0  2023-12-19 06:40:41  {'class': 'negative', 'polarity': -0.1, 'subje...
# 1  2023-12-19 06:03:24  {'class': 'neutral', 'polarity': 0.0, 'subject...
# 2  2023-12-19 05:55:14  {'class': 'positive', 'polarity': 0.05, 'subje...
# 3  2023-12-19 05:35:26  {'class': 'positive', 'polarity': 0.5, 'subjec...
# 4  2023-12-19 05:31:08  {'class': 'neutral', 'polarity': 0.0, 'subject...
#
#           source     subject  \
# 0     CryptoNews     altcoin
# 1     CryptoNews  blockchain
# 2     CryptoNews  blockchain
# 3  CoinTelegraph  blockchain
# 4  CoinTelegraph    ethereum
#
#                                                 text  \
# 0  Grayscale CEO Michael Sonnenshein believes the...
# 1  In an exclusive interview with CryptoNews, Man...
# 2  According to the Federal Court ruling on Decem...
# 3  Some suggest EVM inscriptions are the latest w...
# 4  A decision by bloXroute Labs to start censorin...
#
#                                                title  \
# 0  Grayscale CEO Calls for Simultaneous Approval ...
# 1  Indian Government is Actively Collaborating Wi...
# 2  Judge Approves Settlement: Binance to Pay $1.5...
# 3  Why a gold rush for inscriptions has broken ha...
# 4  ‘Concerning precedent’ — bloXroute Labs' MEV r...
#
#                                                  url  label
# 0  https://cryptonews.comhttps://cryptonews.com/n...     -1
# 1  https://cryptonews.comhttps://cryptonews.com/n...      0
# 2  https://cryptonews.comhttps://cryptonews.com/n...      1
# 3  https://cointelegraph.com/news/inscriptions-ev...      1
# 4  https://cointelegraph.com/news/concerning-prec...      0

# %% [markdown]
# ## Train, validation and test splits

# %%
from sklearn.model_selection import train_test_split

train, retrain = train_test_split(data, random_state=42, test_size=0.3, shuffle=True, stratify=data['label'])

train, test = train_test_split(train, random_state=42, test_size=0.2, shuffle=True, stratify=train['label'])

print("Train Shape:",train.shape)
print("Test Shape:",test.shape)
print("Retrain Shape:",retrain.shape)
# Out:
# Train Shape: (17380, 8)
# Test Shape: (4345, 8)
# Retrain Shape: (9312, 8)

# %%
data['label'].value_counts()
# Out:
# label
#  1    13964
#  0    10555
# -1     6518
# Name: count, dtype: int64

# %%
train['label'].value_counts()
# Out:
# label
#  1    7819
#  0    5910
# -1    3651
# Name: count, dtype: int64

# %%
X_train = train['title']+" "+train['text']
y_train = train['label']

print("X Train Shape:",X_train.shape)
print("y Train Shape:",y_train.shape)
# Out:
# X Train Shape: (17380,)
# y Train Shape: (17380,)

# %% [markdown]
# ## Train the model

# %%
# Entrenar el modelo
pipeline.fit(X_train, y_train)
# Out:
# /workspaces/crypto-news-classification-E2E-MLOps-ZC/.venv/lib/python3.10/site-packages/sklearn/svm/_base.py:1235: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# Pipeline(steps=[('preprocess',
#                  LinguisticPreprocessor(nlp=<spacy.lang.en.English object at 0x72c112f1a890>)),
#                 ('vectorizer', CountVectorizer()),
#                 ('classifier', LinearSVC())])

# %% [markdown]
# ## Evaluate the model

# %%
from sklearn.metrics import classification_report

X_test = test['title']+" "+test['text']
y_test = test['label']

predictions = pipeline.predict(X_test)

print(classification_report(y_test, predictions)) #, target_names=["non-biased", "biased"]))
# Out:
#               precision    recall  f1-score   support
#
#           -1       0.52      0.50      0.51       912
#            0       0.59      0.62      0.60      1478
#            1       0.69      0.68      0.68      1955
#
#     accuracy                           0.62      4345
#    macro avg       0.60      0.60      0.60      4345
# weighted avg       0.62      0.62      0.62      4345
